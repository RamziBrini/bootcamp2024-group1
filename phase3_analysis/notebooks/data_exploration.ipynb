# %%
import pandas as pd

# Load the data
data = pd.read_csv('../data/pizza_recipes.csv')

# Display the first few rows
print(data.head().to_string(index=False))

# Display the first column
data["name"]
# Out:
#        name       dough        sauce                                            toppings                                 preparation                 cooking  temperature  time
#  Margherita Basic dough Tomato sauce                                   Mozzarella, Basil Roll out dough, spread sauce, add toppings. Bake for 10-12 minutes.          220    12
#   Pepperoni Basic dough Tomato sauce                               Mozzarella, Pepperoni Roll out dough, spread sauce, add toppings. Bake for 10-12 minutes.          220    12
# BBQ Chicken Basic dough    BBQ sauce            Mozzarella, Chicken, Red Onion, Cilantro             Spread BBQ sauce, add toppings. Bake for 12-15 minutes.          230    14
#  Vegetarian Basic dough Tomato sauce Mozzarella, Bell Peppers, Onions, Olives, Mushrooms Roll out dough, spread sauce, add toppings. Bake for 10-12 minutes.          220    11
# ...

# %%
data.head()
# Out:
#           name        dough         sauce  \
# 0   Margherita  Basic dough  Tomato sauce
# 1    Pepperoni  Basic dough  Tomato sauce
# 2  BBQ Chicken  Basic dough     BBQ sauce
# 3   Vegetarian  Basic dough  Tomato sauce
# 4     Hawaiian  Basic dough  Tomato sauce
#
#                                             toppings  \
# 0                                  Mozzarella, Basil
# 1                              Mozzarella, Pepperoni
# 2           Mozzarella, Chicken, Red Onion, Cilantro
# 3  Mozzarella, Bell Peppers, Onions, Olives, Mush...
# 4                         Mozzarella, Ham, Pineapple
#
#                                    preparation                  cooking  \
# 0  Roll out dough, spread sauce, add toppings.  Bake for 10-12 minutes.
# 1  Roll out dough, spread sauce, add toppings.  Bake for 10-12 minutes.
# 2              Spread BBQ sauce, add toppings.  Bake for 12-15 minutes.
# 3  Roll out dough, spread sauce, add toppings.  Bake for 10-12 minutes.
# ...

# %%
data.describe()
# Out:
#        temperature       time
# count    20.000000  20.000000
# mean    222.500000  12.150000
# std       4.135851   1.225819
# min     220.000000  10.000000
# 25%     220.000000  11.750000
# 50%     220.000000  12.000000
# 75%     225.000000  13.000000
# max     230.000000  14.000000

# %%
data
# Out:
#                       name        dough          sauce  \
# 0               Margherita  Basic dough   Tomato sauce
# 1                Pepperoni  Basic dough   Tomato sauce
# 2              BBQ Chicken  Basic dough      BBQ sauce
# 3               Vegetarian  Basic dough   Tomato sauce
# 4                 Hawaiian  Basic dough   Tomato sauce
# 5                  Supreme  Basic dough   Tomato sauce
# 6             Meat Lover's  Basic dough   Tomato sauce
# 7       Mushroom & Truffle  Basic dough  Truffle sauce
# 8              Four Cheese  Basic dough  Alfredo sauce
# 9      Spinach & Artichoke  Basic dough  Alfredo sauce
# 10         Buffalo Chicken  Basic dough  Buffalo sauce
# 11         Pesto & Chicken  Basic dough    Pesto sauce
# 12                   Greek  Basic dough      Olive oil
# 13       Margherita Romana  Basic dough   Tomato sauce
# 14             Capricciosa  Basic dough   Tomato sauce
# 15               BBQ Bacon  Basic dough      BBQ sauce
# ...
